# %%
# Import the pyplot module from matplotlib as plt and make sure 
# plots appear in the notebook using '%matplotlib inline'%matplotlib inline
import matplotlib.pyplot as plt 
import pandas as pd
import numpy as np

# %%
# Create a simple plot using plt.plot()
plt.plot();

# %%
# Plot a single Python list
plt.plot([1,2,3,4]);

# %%
# Create two lists, one called X, one called y, each with 5 numbers in them
x = [1, 2, 3, 4]
y = [11, 22, 33, 44]
plt.plot(x,y);

# %%
## Create a plot using plt.subplots() and then add X & y on the axes
#1st method 
fig = plt.figure() # creates a figure 
ax = fig.add_subplot() # adds some axes 
plt.show()

# %%
#2nd method
fig = plt.figure() # create a figure 
ax = fig.add_axes([1,1,1,1])
ax.plot(x,y) # add some data
plt.show()

# %%
# 3rd method recommended 

fig, ax = plt.subplots()
ax.plot(x,[50,190,150,200]); # add some data 
type(fig), type(ax)
# Out:
# (matplotlib.figure.Figure, matplotlib.axes._subplots.AxesSubplot)

# %% [markdown]
# ## Matplotlib workflow

# %%
# import matplotlib and get it ready for plotting in jupyter 
# %matplotlib inline
import matplotlib.pyplot as plt 

# 1. Prepare data 
x = [1,2,3,4]
y = [11,22,3,44]

# 2. Setup plot
fig, ax = plt.subplots(figsize = (10,10))

# 3. plot data 
ax.plot(x,y )

# 4.customize plot
ax.set(title = "simple plot", 
       xlabel= "x-axis",
       ylabel= "y-axis")

# 5. Save & show ( you save thw whole figure ) 
fig.savefig("sample-plot.png")

# %% [markdown]
# ## Making figures with Numpy arrays

# %%
# Import NumPy as np
import numpy as np

# %%
# create some data 
x = np.linspace(0,10,100)
fig, ax =plt.subplots() 
# 2 plot the data (its a line plot)
ax.plot(x, x**2);
# Lets creat a scatter data

# %%
# Use same data to create a scatter plot
fig, ax =plt.subplots()
ax.scatter(x,np.exp(x));

# %%
# another scatter plot
fig, ax =plt.subplots()
ax.scatter(x, np.sin(x));

# %%
# Make a plot from dictionary 
# The keys of the dictionary should be the food name and the values their price
# Create a Python dictionary of 3 of your favourite foods with 
nut_butter_prices = {"almond":10,"peanut": 15, "cashew":20 }
fig, ax = plt.subplots()
ax.bar(nut_butter_prices.keys(),nut_butter_prices.values())# x and y 
ax.set(title = " Shree's nut butter store", ylabel='Price ($)');

# %%
# Make some data for histograms 

x = np.random.rand(100)
fig, ax = plt.subplots()
ax.hist(x);

# %% [markdown]
# ## Two options for subplots

# %%
# subsplot option1 
fig, ((ax1,ax2), (ax3,ax4)) = plt.subplots(nrows=2,
                                          ncols=2,
                                          figsize=(10,5))
# plt to each different axis 
ax1.plot(x,x/2);
ax2.scatter(np.random.random(10), np.random.random(10))
ax3.bar(nut_butter_prices.keys(),nut_butter_prices.values())
ax4.hist(np.random.randn(1000));

# %%
# Subplot option 2 

fig, ax  = plt.subplots(nrows=2,
                        ncols=2,
                        figsize=(10,5))
# plt to each different index 
ax[0,0].plot(x,x/2);
ax[0,1].scatter(np.random.random(10), np.random.random(10));
ax[1,0].bar(nut_butter_prices.keys(),nut_butter_prices.values());
ax[1,1].hist(np.random.randn(1000));

# %% [markdown]
# ## Ploting from pandas Dataframes

# %%
import pandas as pd

# %%
# Make a datframe 
car_sales = pd.read_csv("car-sales.csv")
car_sales
# Out:
#    Unnamed: 0    Make Colour  Odometer (KM)  Doors       Price
# 0           0  Toyota  White         150043      4   $4,000.00
# 1           1   Honda    Red          87899      4   $5,000.00
# 2           2  Toyota   Blue          32549      3   $7,000.00
# 3           3     BMW  Black          11179      5  $22,000.00
# 4           4  Nissan  White         213095      4   $3,500.00
# 5           5  Toyota  Green          99213      4   $4,500.00
# 6           6   Honda   Blue          45698      4   $7,500.00
# 7           7   Honda   Blue          54738      4   $7,000.00
# 8           8  Toyota  White          60000      4   $6,250.00
# 9           9  Nissan  White          31600      4   $9,700.00

# %% [markdown]
# In [3]: ts = pd.Series(np.random.randn(1000),
#    ...:                index=pd.date_range('1/1/2000', periods=1000))
#    ...:
#
# In [4]: ts = ts.cumsum()
#
# In [5]: ts.plot()
# Out[5]: <matplotlib.axes._subplots.AxesSubplot at 0x7f3d08e14790>

# %%
ts = pd.Series(np.random.randn(1000),
               index=pd.date_range('1/1/2020', periods=1000))
ts = ts.cumsum()
ts.plot();

# %%
car_sales["Price"] = car_sales["Price"].str.replace('[\$\,\.]', '')
car_sales
# Out:
#    Unnamed: 0    Make Colour  Odometer (KM)  Doors    Price
# 0           0  Toyota  White         150043      4   400000
# 1           1   Honda    Red          87899      4   500000
# 2           2  Toyota   Blue          32549      3   700000
# 3           3     BMW  Black          11179      5  2200000
# 4           4  Nissan  White         213095      4   350000
# 5           5  Toyota  Green          99213      4   450000
# 6           6   Honda   Blue          45698      4   750000
# 7           7   Honda   Blue          54738      4   700000
# 8           8  Toyota  White          60000      4   625000
# 9           9  Nissan  White          31600      4   970000

# %%
# Remove last two zeros
car_sales["Price"] = car_sales["Price"].str[:-2]
car_sales
# Out:
#    Unnamed: 0    Make Colour  Odometer (KM)  Doors  Price
# 0           0  Toyota  White         150043      4   4000
# 1           1   Honda    Red          87899      4   5000
# 2           2  Toyota   Blue          32549      3   7000
# 3           3     BMW  Black          11179      5  22000
# 4           4  Nissan  White         213095      4   3500
# 5           5  Toyota  Green          99213      4   4500
# 6           6   Honda   Blue          45698      4   7500
# 7           7   Honda   Blue          54738      4   7000
# 8           8  Toyota  White          60000      4   6250
# 9           9  Nissan  White          31600      4   9700

# %%
car_sales["Sales Date"] = pd.date_range('1/1/2020', periods=len(car_sales))
car_sales
# Out:
#    Unnamed: 0    Make Colour  Odometer (KM)  Doors  Price Sales Date
# 0           0  Toyota  White         150043      4   4000 2020-01-01
# 1           1   Honda    Red          87899      4   5000 2020-01-02
# 2           2  Toyota   Blue          32549      3   7000 2020-01-03
# 3           3     BMW  Black          11179      5  22000 2020-01-04
# 4           4  Nissan  White         213095      4   3500 2020-01-05
# 5           5  Toyota  Green          99213      4   4500 2020-01-06
# 6           6   Honda   Blue          45698      4   7500 2020-01-07
# 7           7   Honda   Blue          54738      4   7000 2020-01-08
# 8           8  Toyota  White          60000      4   6250 2020-01-09
# 9           9  Nissan  White          31600      4   9700 2020-01-10

# %%
car_sales["Total Sales "] = car_sales["Price"].astype(int).cumsum()
car_sales
# Out:
#    Unnamed: 0    Make Colour  Odometer (KM)  Doors  Price Sales Date  \
# 0           0  Toyota  White         150043      4   4000 2020-01-01
# 1           1   Honda    Red          87899      4   5000 2020-01-02
# 2           2  Toyota   Blue          32549      3   7000 2020-01-03
# 3           3     BMW  Black          11179      5  22000 2020-01-04
# 4           4  Nissan  White         213095      4   3500 2020-01-05
# 5           5  Toyota  Green          99213      4   4500 2020-01-06
# 6           6   Honda   Blue          45698      4   7500 2020-01-07
# 7           7   Honda   Blue          54738      4   7000 2020-01-08
# 8           8  Toyota  White          60000      4   6250 2020-01-09
# 9           9  Nissan  White          31600      4   9700 2020-01-10
#
#    Total Sales
# 0          4000
# 1          9000
# 2         16000
# 3         38000
# 4         41500
# 5         46000
# 6         53500
# 7         60500
# 8         66750
# 9         76450

# %%
## Lets plot the total sales amd reassign price to int 

car_sales["Price"] = car_sales["Price"].astype(int)

# Plot scatter plot with price column as numeric 

car_sales.plot(x ="Odometer (KM)",y="Price", kind="scatter");

# %%
# How about a bar graph 
x = np.random.rand(10,4)
x
# Turn it into a Dataframe 

df = pd.DataFrame(x, columns = ['a', 'b', 'c', 'd'])
df
# Out:
#           a         b         c         d
# 0  0.872025  0.434579  0.575464  0.726317
# 1  0.532225  0.636367  0.859615  0.162177
# 2  0.566972  0.028314  0.069471  0.191544
# 3  0.470207  0.016415  0.212525  0.011461
# 4  0.589342  0.876454  0.036265  0.252344
# 5  0.412239  0.242374  0.350807  0.351403
# 6  0.848687  0.764793  0.819365  0.837165
# 7  0.022853  0.077117  0.983992  0.280215
# 8  0.696698  0.129198  0.357718  0.222918
# 9  0.935334  0.120135  0.104233  0.710006

# %%
df.plot.bar();

# %%
df.plot(kind='bar');

# %%
car_sales
# Out:
#    Unnamed: 0    Make Colour  Odometer (KM)  Doors  Price Sales Date  \
# 0           0  Toyota  White         150043      4   4000 2020-01-01
# 1           1   Honda    Red          87899      4   5000 2020-01-02
# 2           2  Toyota   Blue          32549      3   7000 2020-01-03
# 3           3     BMW  Black          11179      5  22000 2020-01-04
# 4           4  Nissan  White         213095      4   3500 2020-01-05
# 5           5  Toyota  Green          99213      4   4500 2020-01-06
# 6           6   Honda   Blue          45698      4   7500 2020-01-07
# 7           7   Honda   Blue          54738      4   7000 2020-01-08
# 8           8  Toyota  White          60000      4   6250 2020-01-09
# 9           9  Nissan  White          31600      4   9700 2020-01-10
#
#    Total Sales
# 0          4000
# 1          9000
# 2         16000
# 3         38000
# 4         41500
# 5         46000
# 6         53500
# 7         60500
# 8         66750
# 9         76450

# %%
car_sales.plot(x = "Make", y="Odometer (KM)", kind = "bar");

# %%
# How about histogram 

car_sales["Odometer (KM)"].plot.hist();

# %%
car_sales["Odometer (KM)"].plot(kind='hist');

# %% [markdown]
# ## Lets try Heart diease

# %%
heart_disease = pd.read_csv("heart-disease.csv")
heart_disease.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
# Create a histogram of age 
heart_disease["age"].plot.hist(bins = 50);

# %%
heart_disease.plot.hist(figsize = (10,30), subplots = True);

# %% [markdown]
# ### Which one should you use ? ( pyplot vs matplotlib OO method ?)
#
# * when plotting something quickly , okay to use the pyplot method
# * when plotting something more advanced,  use the OO method

# %%
heart_disease.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
over_50 = heart_disease[heart_disease["age"]>50]
over_50.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
# 5   57    1   0       140   192    0        1      148      0      0.4      1
# 6   56    0   1       140   294    0        0      153      0      1.3      1
#
#    ca  thal  target
# 0   0     1       1
# 3   0     2       1
# 4   0     2       1
# 5   0     1       1
# 6   0     2       1

# %%
## Pyplot method 

over_50.plot(kind='scatter',
           x='age',
           y ='chol',
           c='target');

# %%
## OO method 
fix, ax =plt.subplots(figsize=(10,6))
over_50.plot(kind='scatter', 
            x = 'age',
            y ='chol',
            c = 'target',
            ax=ax);

ax.set_xlim([45,100])
# Out:
# (45, 100)

# %%
## OO method from scratch 

fig, ax = plt.subplots(figsize=(10,6))

# plot the data 
scatter = ax.scatter(x = over_50["age"],
                     y = over_50["chol"],
                     c = over_50["target"])

# customize the plot 
ax.set(title ="Heart Diease and Cholesterol Levels",
       xlabel = "Age",
       ylabel = "Cholesterol")

#Add a legend 
ax.legend(*scatter.legend_elements(), title="Target")

# Add a horizontal line
ax.axhline(over_50["chol"].mean(),
           linestyle= '--');

# %%
# subplot of chol, age, thalach

# %%
# subplot of chol, age , thalach
fig, (ax0, ax1) = plt.subplots(nrows = 2,
                               ncols = 1,
                               figsize = (10,10),
                               sharex =True)

# add data to axes0
scatter = ax0.scatter(x= over_50["age"],
                      y= over_50["chol"],
                      c=over_50["target"],)
# customize ax0
ax0.set(title="Heart Diease and Cholesterol Levels",
        ylabel="Cholesterol")

# Add a legend 
ax0.legend(*scatter.legend_elements(), title ="Target")

# Add a meanline 
ax0.axhline (y =over_50["chol"].mean(),
             linestyle='--')


# add data to axes1
scatter = ax1.scatter(x= over_50["age"],
                      y= over_50["thalach"],
                     c=over_50["target"],)
# customize ax1
ax1.set(title="Heart Diease and max Heart Rate",
       xlabel="Age",
       ylabel="Max Heart Rate")

# Add a legend 
ax1.legend(*scatter.legend_elements(), title ="Target")

# Add a meanline 
ax1.axhline (y =over_50["thalach"].mean(),
             linestyle='--');

# Add a title to the figure
fig.suptitle("Heart disease Analysis",fontsize=16, fontweight="bold" );

# %% [markdown]
# ## customizing Matplotlib and getting sytlish

# %%
## see the the different styles avialable 
plt.style.available
# Out:
# ['bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark-palette',
#  'seaborn-dark',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'seaborn',
#  'Solarize_Light2',
#  'tableau-colorblind10',
#  '_classic_test']

# %%
car_sales.head()
# Out:
#    Unnamed: 0    Make Colour  Odometer (KM)  Doors  Price Sales Date  \
# 0           0  Toyota  White         150043      4   4000 2020-01-01
# 1           1   Honda    Red          87899      4   5000 2020-01-02
# 2           2  Toyota   Blue          32549      3   7000 2020-01-03
# 3           3     BMW  Black          11179      5  22000 2020-01-04
# 4           4  Nissan  White         213095      4   3500 2020-01-05
#
#    Total Sales
# 0          4000
# 1          9000
# 2         16000
# 3         38000
# 4         41500

# %%
car_sales["Price"].plot();

# %%
plt.style.use('seaborn-whitegrid')

# %%
car_sales["Price"].plot();

# %%
plt.style.use('seaborn')

# %%
car_sales["Price"].plot();

# %%
car_sales.plot(x="Odometer (KM)", y="Price", kind ="scatter");

# %%
plt.style.use('ggplot')

# %%
car_sales["Price"].plot();

# %%
## Set the style
plt.style.use('seaborn-whitegrid')

## OO method from scratch
fig, ax = plt.subplots(figsize=(10,6))

# plot the data 
scatter = ax.scatter(x = over_50["age"],
                     y = over_50["chol"],
                     c = over_50["target"], 
                     cmap="winter")

# customize the plot 
ax.set(title ="Heart Diease and Cholesterol Levels",
       xlabel = "Age",
       ylabel = "Cholesterol")

#Add a legend 
ax.legend(*scatter.legend_elements(), title="Target")

# Add a horizontal line
ax.axhline(over_50["chol"].mean(),
           linestyle= '--');

# %%
## customizing the y and xaxis limitation 

# subplot of chol, age , thalach
fig, (ax0, ax1) = plt.subplots(nrows = 2,
                               ncols = 1,
                               figsize = (10,10),
                               sharex =True)

# add data to axes0
scatter = ax0.scatter(x= over_50["age"],
                      y= over_50["chol"],
                      c=over_50["target"],
                     cmap="winter")
# customize ax0
ax0.set(title="Heart Diease and Cholesterol Levels",
        ylabel="Cholesterol")

# change the x axis limits 
ax0.set_xlim([50, 80])



# Add a legend 
ax0.legend(*scatter.legend_elements(), title ="Target")

# Add a meanline 
ax0.axhline (y =over_50["chol"].mean(),
             linestyle='--')


# add data to axes1
scatter = ax1.scatter(x= over_50["age"],
                      y= over_50["thalach"],
                     c=over_50["target"],
                     cmap="summer")
# customize ax1
ax1.set(title="Heart Diease and max Heart Rate",
       xlabel="Age",
       ylabel="Max Heart Rate")
# change the x axis limits 
ax1.set_xlim([50, 80])
ax1.set_ylim([60, 200])


# Add a legend 
ax1.legend(*scatter.legend_elements(), title ="Target")

# Add a meanline 
ax1.axhline (y =over_50["thalach"].mean(),
             linestyle='--');

# Add a title to the figure
fig.suptitle("Heart disease Analysis",fontsize=16, fontweight="bold" );

# %%
fig.savefig ("heart-disease-analysis-plot-saved-with-code.png")
